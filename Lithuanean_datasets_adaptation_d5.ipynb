# %% [markdown]
# <h3>Data set #5:<br>
# Foreign direct investment per capita at the end of the year (2014) <br>
# http://osp.stat.gov.lt/en/statistiniu-rodikliu-analize?portletFormName=visualization&hash=b3226318-f641-4d66-847f-b9df5d05eb30</h3>

# %%
#pulling csv data from file
import csv
filename='Source_datasets/Exported matrix table_d5.csv'
with open(filename, 'r') as f:
    data = list(csv.reader(f))
#print (data)
#print (f)
for row_num in range(0,len(data)):
    print (data[row_num])
# Out:
# ['\ufeff', '', 'Foreign direct investment per capita at the end of the year | EUR']
# ['Republic of Lithuania', '2014', '4363']
# ['', '2015', '4673']
# ['Alytus county', '2014', '805']
# ['', '2015', '949']
# ['Alytus t. mun.', '2014', '1219']
# ['', '2015', '1376']
# ['Alytus d. mun.', '2014', '848']
# ['', '2015', '969']
# ['Druskininkai mun.', '2014', '1256']
# ['', '2015', '1725']
# ['Lazdijai d. mun.', '2014', '2']
# ['', '2015', '4']
# ['Varėna d. mun.', '2014', '92']
# ['', '2015', '65']
# ['Kaunas county', '2014', '2427']
# ['', '2015', '2612']
# ['Birštonas mun.', '2014', '48']
# ['', '2015', '60']
# ['Jonava d. mun.', '2014', '79']
# ['', '2015', '140']
# ['Kaišiadorys d. mun.', '2014', '92']
# ['', '2015', '142']
# ['Kaunas c. mun.', '2014', '3310']
# ['', '2015', '3446']
# ['Kaunas d. mun.', '2014', '1206']
# ['', '2015', '1279']
# ['Kėdainiai d. mun.', '2014', '5408']
# ['', '2015', '6573']
# ['Prienai d. mun.', '2014', '85']
# ['', '2015', '109']
# ['Raseiniai d. mun.', '2014', '912']
# ['', '2015', '903']
# ['Klaipėda county', '2014', '3100']
# ['', '2015', '3732']
# ['Klaipėda c. mun.', '2014', '4457']
# ['', '2015', '5578']
# ['Klaipėda d. mun.', '2014', '4666']
# ['', '2015', '4815']
# ['Kretinga d. mun.', '2014', '200']
# ['', '2015', '256']
# ['Neringa mun.', '2014', '2501']
# ['', '2015', '2609']
# ['Palanga t. mun.', '2014', '1958']
# ['', '2015', '2101']
# ['Skuodas d. mun.', '2014', '128']
# ['', '2015', '137']
# ['Šilutė d. mun.', '2014', '588']
# ['', '2015', '981']
# ['Marijampolė county', '2014', '904']
# ['', '2015', '944']
# ['Kalvarija mun.', '2014', '24']
# ['', '2015', '36']
# ['Kazlų Rūda mun.', '2014', '7502']
# ['', '2015', '8077']
# ['Marijampolė mun.', '2014', '459']
# ['', '2015', '410']
# ['Marijampolė d. mun.', '2014', '']
# ['', '2015', '']
# ['Šakiai d. mun.', '2014', '469']
# ['', '2015', '457']
# ['Vilkaviškis d. mun.', '2014', '60']
# ['', '2015', '85']
# ['Panevėžys county', '2014', '1184']
# ['', '2015', '1369']
# ['Biržai d. mun.', '2014', '379']
# ['', '2015', '903']
# ['Kupiškis d. mun.', '2014', '178']
# ['', '2015', '183']
# ['Panevėžys c. mun.', '2014', '2446']
# ['', '2015', '2614']
# ['Panevėžys d. mun.', '2014', '331']
# ['', '2015', '661']
# ['Pasvalys d. mun.', '2014', '275']
# ['', '2015', '308']
# ['Rokiškis d. mun.', '2014', '405']
# ['', '2015', '421']
# ['Šiauliai county', '2014', '605']
# ['', '2015', '641']
# ['Akmenė d. mun.', '2014', '2174']
# ['', '2015', '2247']
# ['Joniškis d. mun.', '2014', '22']
# ['', '2015', '31']
# ['Kelmė d. mun.', '2014', '8']
# ['', '2015', '6']
# ['Pakruojis d. mun.', '2014', '1498']
# ['', '2015', '1575']
# ['Radviliškis d. mun.', '2014', '147']
# ['', '2015', '173']
# ['Šiauliai c. mun.', '2014', '663']
# ['', '2015', '709']
# ['Šiauliai d. mun.', '2014', '379']
# ['', '2015', '408']
# ['Tauragė county', '2014', '212']
# ['', '2015', '243']
# ['Jurbarkas d. mun.', '2014', '48']
# ['', '2015', '48']
# ['Pagėgiai mun.', '2014', '25']
# ['', '2015', '10']
# ['Šilalė d. mun.', '2014', '6']
# ['', '2015', '5']
# ['Tauragė d. mun.', '2014', '487']
# ['', '2015', '565']
# ['Telšiai county', '2014', '1999']
# ['', '2015', '1867']
# ['Mažeikiai d. mun.', '2014', '5048']
# ['', '2015', '4454']
# ['Plungė d. mun.', '2014', '100']
# ['', '2015', '460']
# ['Rietavas mun.', '2014', '1']
# ['', '2015', '1']
# ['Telšiai d. mun.', '2014', '76']
# ['', '2015', '81']
# ['Utena county', '2014', '1644']
# ['', '2015', '1375']
# ['Anykščiai d. mun.', '2014', '61']
# ['', '2015', '366']
# ['Ignalina d. mun.', '2014', '214']
# ['', '2015', '225']
# ['Molėtai d. mun.', '2014', '61']
# ['', '2015', '101']
# ['Utena d. mun.', '2014', '5274']
# ['', '2015', '4144']
# ['Visaginas mun.', '2014', '476']
# ['', '2015', '387']
# ['Zarasai d. mun.', '2014', '60']
# ['', '2015', '60']
# ['Vilnius county', '2014', '11235']
# ['', '2015', '11830']
# ['Elektrėnai mun.', '2014', '3141']
# ['', '2015', '3660']
# ['Šalčininkai d. mun.', '2014', '3']
# ['', '2015', '16']
# ['Širvintos d. mun.', '2014', '41']
# ['', '2015', '75']
# ['Švenčionys d. mun.', '2014', '2157']
# ['', '2015', '2300']
# ['Trakai d. mun.', '2014', '1507']
# ['', '2015', '1609']
# ['Ukmergė d. mun.', '2014', '1224']
# ['', '2015', '1538']
# ['Vilnius c. mun.', '2014', '15938']
# ['', '2015', '16729']
# ['Vilnius d. mun.', '2014', '2053']
# ['', '2015', '1888']

# %%
#remove aggregated rows, as aggregation will take place later e.g. in pivotjs
keysList=['Republic','county']
tobedeletedList=[]

updated_lengh=len(data)
for row_num in range(0,updated_lengh):
    for key in keysList:
        #print (key)
        if key in data[row_num][0]:
            tobedeletedList.append(row_num)
            tobedeletedList.append(row_num+1)#for 2015 rows

print (tobedeletedList)

for aggregated_row_num in tobedeletedList:
    #print (data[aggregated_row_num])
    data[aggregated_row_num]=['']
    #tobedeletedList[:] = [x - 1 for x in tobedeletedList]
   #print (tobedeletedList)
    
for row_num in range(0,len(data)):
    print (data[row_num])
# Out:
# [1, 2, 3, 4, 15, 16, 33, 34, 49, 50, 63, 64, 77, 78, 93, 94, 103, 104, 113, 114, 127, 128]
# ['\ufeff', '', 'Foreign direct investment per capita at the end of the year | EUR']
# ['']
# ['']
# ['']
# ['']
# ['Alytus t. mun.', '2014', '1219']
# ['', '2015', '1376']
# ['Alytus d. mun.', '2014', '848']
# ['', '2015', '969']
# ['Druskininkai mun.', '2014', '1256']
# ['', '2015', '1725']
# ['Lazdijai d. mun.', '2014', '2']
# ['', '2015', '4']
# ['Varėna d. mun.', '2014', '92']
# ['', '2015', '65']
# ['']
# ['']
# ['Birštonas mun.', '2014', '48']
# ['', '2015', '60']
# ['Jonava d. mun.', '2014', '79']
# ['', '2015', '140']
# ['Kaišiadorys d. mun.', '2014', '92']
# ['', '2015', '142']
# ['Kaunas c. mun.', '2014', '3310']
# ['', '2015', '3446']
# ['Kaunas d. mun.', '2014', '1206']
# ['', '2015', '1279']
# ['Kėdainiai d. mun.', '2014', '5408']
# ['', '2015', '6573']
# ['Prienai d. mun.', '2014', '85']
# ['', '2015', '109']
# ['Raseiniai d. mun.', '2014', '912']
# ['', '2015', '903']
# ['']
# ['']
# ['Klaipėda c. mun.', '2014', '4457']
# ['', '2015', '5578']
# ['Klaipėda d. mun.', '2014', '4666']
# ['', '2015', '4815']
# ['Kretinga d. mun.', '2014', '200']
# ['', '2015', '256']
# ['Neringa mun.', '2014', '2501']
# ['', '2015', '2609']
# ['Palanga t. mun.', '2014', '1958']
# ['', '2015', '2101']
# ['Skuodas d. mun.', '2014', '128']
# ['', '2015', '137']
# ['Šilutė d. mun.', '2014', '588']
# ['', '2015', '981']
# ['']
# ['']
# ['Kalvarija mun.', '2014', '24']
# ['', '2015', '36']
# ['Kazlų Rūda mun.', '2014', '7502']
# ['', '2015', '8077']
# ['Marijampolė mun.', '2014', '459']
# ['', '2015', '410']
# ['Marijampolė d. mun.', '2014', '']
# ['', '2015', '']
# ['Šakiai d. mun.', '2014', '469']
# ['', '2015', '457']
# ['Vilkaviškis d. mun.', '2014', '60']
# ['', '2015', '85']
# ['']
# ['']
# ['Biržai d. mun.', '2014', '379']
# ['', '2015', '903']
# ['Kupiškis d. mun.', '2014', '178']
# ['', '2015', '183']
# ['Panevėžys c. mun.', '2014', '2446']
# ['', '2015', '2614']
# ['Panevėžys d. mun.', '2014', '331']
# ['', '2015', '661']
# ['Pasvalys d. mun.', '2014', '275']
# ['', '2015', '308']
# ['Rokiškis d. mun.', '2014', '405']
# ['', '2015', '421']
# ['']
# ['']
# ['Akmenė d. mun.', '2014', '2174']
# ['', '2015', '2247']
# ['Joniškis d. mun.', '2014', '22']
# ['', '2015', '31']
# ['Kelmė d. mun.', '2014', '8']
# ['', '2015', '6']
# ['Pakruojis d. mun.', '2014', '1498']
# ['', '2015', '1575']
# ['Radviliškis d. mun.', '2014', '147']
# ['', '2015', '173']
# ['Šiauliai c. mun.', '2014', '663']
# ['', '2015', '709']
# ['Šiauliai d. mun.', '2014', '379']
# ['', '2015', '408']
# ['']
# ['']
# ['Jurbarkas d. mun.', '2014', '48']
# ['', '2015', '48']
# ['Pagėgiai mun.', '2014', '25']
# ['', '2015', '10']
# ['Šilalė d. mun.', '2014', '6']
# ['', '2015', '5']
# ['Tauragė d. mun.', '2014', '487']
# ['', '2015', '565']
# ['']
# ['']
# ['Mažeikiai d. mun.', '2014', '5048']
# ['', '2015', '4454']
# ['Plungė d. mun.', '2014', '100']
# ['', '2015', '460']
# ['Rietavas mun.', '2014', '1']
# ['', '2015', '1']
# ['Telšiai d. mun.', '2014', '76']
# ['', '2015', '81']
# ['']
# ['']
# ['Anykščiai d. mun.', '2014', '61']
# ['', '2015', '366']
# ['Ignalina d. mun.', '2014', '214']
# ['', '2015', '225']
# ['Molėtai d. mun.', '2014', '61']
# ['', '2015', '101']
# ['Utena d. mun.', '2014', '5274']
# ['', '2015', '4144']
# ['Visaginas mun.', '2014', '476']
# ['', '2015', '387']
# ['Zarasai d. mun.', '2014', '60']
# ['', '2015', '60']
# ['']
# ['']
# ['Elektrėnai mun.', '2014', '3141']
# ['', '2015', '3660']
# ['Šalčininkai d. mun.', '2014', '3']
# ['', '2015', '16']
# ['Širvintos d. mun.', '2014', '41']
# ['', '2015', '75']
# ['Švenčionys d. mun.', '2014', '2157']
# ['', '2015', '2300']
# ['Trakai d. mun.', '2014', '1507']
# ['', '2015', '1609']
# ['Ukmergė d. mun.', '2014', '1224']
# ['', '2015', '1538']
# ['Vilnius c. mun.', '2014', '15938']
# ['', '2015', '16729']
# ['Vilnius d. mun.', '2014', '2053']
# ['', '2015', '1888']

# %%
#Adding missing municapility value for the Females rows
for row_num in range(1,len(data)):
    #print (len(data[row_num]))
    if (len(data[row_num]))==3:
        if not data[row_num][0]:
            #print (data[row_num])
            data[row_num][0]=data[row_num-1][0]
            #print (data[row_num])
for row_num in range(0,len(data)):
    print (data[row_num])
# Out:
# ['\ufeff', '', 'Foreign direct investment per capita at the end of the year | EUR']
# ['']
# ['']
# ['']
# ['']
# ['Alytus t. mun.', '2014', '1219']
# ['Alytus t. mun.', '2015', '1376']
# ['Alytus d. mun.', '2014', '848']
# ['Alytus d. mun.', '2015', '969']
# ['Druskininkai mun.', '2014', '1256']
# ['Druskininkai mun.', '2015', '1725']
# ['Lazdijai d. mun.', '2014', '2']
# ['Lazdijai d. mun.', '2015', '4']
# ['Varėna d. mun.', '2014', '92']
# ['Varėna d. mun.', '2015', '65']
# ['']
# ['']
# ['Birštonas mun.', '2014', '48']
# ['Birštonas mun.', '2015', '60']
# ['Jonava d. mun.', '2014', '79']
# ['Jonava d. mun.', '2015', '140']
# ['Kaišiadorys d. mun.', '2014', '92']
# ['Kaišiadorys d. mun.', '2015', '142']
# ['Kaunas c. mun.', '2014', '3310']
# ['Kaunas c. mun.', '2015', '3446']
# ['Kaunas d. mun.', '2014', '1206']
# ['Kaunas d. mun.', '2015', '1279']
# ['Kėdainiai d. mun.', '2014', '5408']
# ['Kėdainiai d. mun.', '2015', '6573']
# ['Prienai d. mun.', '2014', '85']
# ['Prienai d. mun.', '2015', '109']
# ['Raseiniai d. mun.', '2014', '912']
# ['Raseiniai d. mun.', '2015', '903']
# ['']
# ['']
# ['Klaipėda c. mun.', '2014', '4457']
# ['Klaipėda c. mun.', '2015', '5578']
# ['Klaipėda d. mun.', '2014', '4666']
# ['Klaipėda d. mun.', '2015', '4815']
# ['Kretinga d. mun.', '2014', '200']
# ['Kretinga d. mun.', '2015', '256']
# ['Neringa mun.', '2014', '2501']
# ['Neringa mun.', '2015', '2609']
# ['Palanga t. mun.', '2014', '1958']
# ['Palanga t. mun.', '2015', '2101']
# ['Skuodas d. mun.', '2014', '128']
# ['Skuodas d. mun.', '2015', '137']
# ['Šilutė d. mun.', '2014', '588']
# ['Šilutė d. mun.', '2015', '981']
# ['']
# ['']
# ['Kalvarija mun.', '2014', '24']
# ['Kalvarija mun.', '2015', '36']
# ['Kazlų Rūda mun.', '2014', '7502']
# ['Kazlų Rūda mun.', '2015', '8077']
# ['Marijampolė mun.', '2014', '459']
# ['Marijampolė mun.', '2015', '410']
# ['Marijampolė d. mun.', '2014', '']
# ['Marijampolė d. mun.', '2015', '']
# ['Šakiai d. mun.', '2014', '469']
# ['Šakiai d. mun.', '2015', '457']
# ['Vilkaviškis d. mun.', '2014', '60']
# ['Vilkaviškis d. mun.', '2015', '85']
# ['']
# ['']
# ['Biržai d. mun.', '2014', '379']
# ['Biržai d. mun.', '2015', '903']
# ['Kupiškis d. mun.', '2014', '178']
# ['Kupiškis d. mun.', '2015', '183']
# ['Panevėžys c. mun.', '2014', '2446']
# ['Panevėžys c. mun.', '2015', '2614']
# ['Panevėžys d. mun.', '2014', '331']
# ['Panevėžys d. mun.', '2015', '661']
# ['Pasvalys d. mun.', '2014', '275']
# ['Pasvalys d. mun.', '2015', '308']
# ['Rokiškis d. mun.', '2014', '405']
# ['Rokiškis d. mun.', '2015', '421']
# ['']
# ['']
# ['Akmenė d. mun.', '2014', '2174']
# ['Akmenė d. mun.', '2015', '2247']
# ['Joniškis d. mun.', '2014', '22']
# ['Joniškis d. mun.', '2015', '31']
# ['Kelmė d. mun.', '2014', '8']
# ['Kelmė d. mun.', '2015', '6']
# ['Pakruojis d. mun.', '2014', '1498']
# ['Pakruojis d. mun.', '2015', '1575']
# ['Radviliškis d. mun.', '2014', '147']
# ['Radviliškis d. mun.', '2015', '173']
# ['Šiauliai c. mun.', '2014', '663']
# ['Šiauliai c. mun.', '2015', '709']
# ['Šiauliai d. mun.', '2014', '379']
# ['Šiauliai d. mun.', '2015', '408']
# ['']
# ['']
# ['Jurbarkas d. mun.', '2014', '48']
# ['Jurbarkas d. mun.', '2015', '48']
# ['Pagėgiai mun.', '2014', '25']
# ['Pagėgiai mun.', '2015', '10']
# ['Šilalė d. mun.', '2014', '6']
# ['Šilalė d. mun.', '2015', '5']
# ['Tauragė d. mun.', '2014', '487']
# ['Tauragė d. mun.', '2015', '565']
# ['']
# ['']
# ['Mažeikiai d. mun.', '2014', '5048']
# ['Mažeikiai d. mun.', '2015', '4454']
# ['Plungė d. mun.', '2014', '100']
# ['Plungė d. mun.', '2015', '460']
# ['Rietavas mun.', '2014', '1']
# ['Rietavas mun.', '2015', '1']
# ['Telšiai d. mun.', '2014', '76']
# ['Telšiai d. mun.', '2015', '81']
# ['']
# ['']
# ['Anykščiai d. mun.', '2014', '61']
# ['Anykščiai d. mun.', '2015', '366']
# ['Ignalina d. mun.', '2014', '214']
# ['Ignalina d. mun.', '2015', '225']
# ['Molėtai d. mun.', '2014', '61']
# ['Molėtai d. mun.', '2015', '101']
# ['Utena d. mun.', '2014', '5274']
# ['Utena d. mun.', '2015', '4144']
# ['Visaginas mun.', '2014', '476']
# ['Visaginas mun.', '2015', '387']
# ['Zarasai d. mun.', '2014', '60']
# ['Zarasai d. mun.', '2015', '60']
# ['']
# ['']
# ['Elektrėnai mun.', '2014', '3141']
# ['Elektrėnai mun.', '2015', '3660']
# ['Šalčininkai d. mun.', '2014', '3']
# ['Šalčininkai d. mun.', '2015', '16']
# ['Širvintos d. mun.', '2014', '41']
# ['Širvintos d. mun.', '2015', '75']
# ['Švenčionys d. mun.', '2014', '2157']
# ['Švenčionys d. mun.', '2015', '2300']
# ['Trakai d. mun.', '2014', '1507']
# ['Trakai d. mun.', '2015', '1609']
# ['Ukmergė d. mun.', '2014', '1224']
# ['Ukmergė d. mun.', '2015', '1538']
# ['Vilnius c. mun.', '2014', '15938']
# ['Vilnius c. mun.', '2015', '16729']
# ['Vilnius d. mun.', '2014', '2053']
# ['Vilnius d. mun.', '2015', '1888']

# %%
#permanent clean of unwanted rows in dataset
tobedeletedList=[]
for row_num in range (1,len(data)):
    if (len(data[row_num])<3):#regarding temporary header size
        #print ("row num{}:{}".format(i,data[row_num]))
        tobedeletedList.append(row_num)
print (tobedeletedList)
for aggregated_row_num in tobedeletedList:
    #print (data[aggregated_row_num])
    del data[aggregated_row_num]
    tobedeletedList[:] = [x - 1 for x in tobedeletedList]
   #print (tobedeletedList)
    
for row_num in range(0,len(data)):
    print (data[row_num])
# Out:
# [1, 2, 3, 4, 15, 16, 33, 34, 49, 50, 63, 64, 77, 78, 93, 94, 103, 104, 113, 114, 127, 128]
# ['\ufeff', '', 'Foreign direct investment per capita at the end of the year | EUR']
# ['Alytus t. mun.', '2014', '1219']
# ['Alytus t. mun.', '2015', '1376']
# ['Alytus d. mun.', '2014', '848']
# ['Alytus d. mun.', '2015', '969']
# ['Druskininkai mun.', '2014', '1256']
# ['Druskininkai mun.', '2015', '1725']
# ['Lazdijai d. mun.', '2014', '2']
# ['Lazdijai d. mun.', '2015', '4']
# ['Varėna d. mun.', '2014', '92']
# ['Varėna d. mun.', '2015', '65']
# ['Birštonas mun.', '2014', '48']
# ['Birštonas mun.', '2015', '60']
# ['Jonava d. mun.', '2014', '79']
# ['Jonava d. mun.', '2015', '140']
# ['Kaišiadorys d. mun.', '2014', '92']
# ['Kaišiadorys d. mun.', '2015', '142']
# ['Kaunas c. mun.', '2014', '3310']
# ['Kaunas c. mun.', '2015', '3446']
# ['Kaunas d. mun.', '2014', '1206']
# ['Kaunas d. mun.', '2015', '1279']
# ['Kėdainiai d. mun.', '2014', '5408']
# ['Kėdainiai d. mun.', '2015', '6573']
# ['Prienai d. mun.', '2014', '85']
# ['Prienai d. mun.', '2015', '109']
# ['Raseiniai d. mun.', '2014', '912']
# ['Raseiniai d. mun.', '2015', '903']
# ['Klaipėda c. mun.', '2014', '4457']
# ['Klaipėda c. mun.', '2015', '5578']
# ['Klaipėda d. mun.', '2014', '4666']
# ['Klaipėda d. mun.', '2015', '4815']
# ['Kretinga d. mun.', '2014', '200']
# ['Kretinga d. mun.', '2015', '256']
# ['Neringa mun.', '2014', '2501']
# ['Neringa mun.', '2015', '2609']
# ['Palanga t. mun.', '2014', '1958']
# ['Palanga t. mun.', '2015', '2101']
# ['Skuodas d. mun.', '2014', '128']
# ['Skuodas d. mun.', '2015', '137']
# ['Šilutė d. mun.', '2014', '588']
# ['Šilutė d. mun.', '2015', '981']
# ['Kalvarija mun.', '2014', '24']
# ['Kalvarija mun.', '2015', '36']
# ['Kazlų Rūda mun.', '2014', '7502']
# ['Kazlų Rūda mun.', '2015', '8077']
# ['Marijampolė mun.', '2014', '459']
# ['Marijampolė mun.', '2015', '410']
# ['Marijampolė d. mun.', '2014', '']
# ['Marijampolė d. mun.', '2015', '']
# ['Šakiai d. mun.', '2014', '469']
# ['Šakiai d. mun.', '2015', '457']
# ['Vilkaviškis d. mun.', '2014', '60']
# ['Vilkaviškis d. mun.', '2015', '85']
# ['Biržai d. mun.', '2014', '379']
# ['Biržai d. mun.', '2015', '903']
# ['Kupiškis d. mun.', '2014', '178']
# ['Kupiškis d. mun.', '2015', '183']
# ['Panevėžys c. mun.', '2014', '2446']
# ['Panevėžys c. mun.', '2015', '2614']
# ['Panevėžys d. mun.', '2014', '331']
# ['Panevėžys d. mun.', '2015', '661']
# ['Pasvalys d. mun.', '2014', '275']
# ['Pasvalys d. mun.', '2015', '308']
# ['Rokiškis d. mun.', '2014', '405']
# ['Rokiškis d. mun.', '2015', '421']
# ['Akmenė d. mun.', '2014', '2174']
# ['Akmenė d. mun.', '2015', '2247']
# ['Joniškis d. mun.', '2014', '22']
# ['Joniškis d. mun.', '2015', '31']
# ['Kelmė d. mun.', '2014', '8']
# ['Kelmė d. mun.', '2015', '6']
# ['Pakruojis d. mun.', '2014', '1498']
# ['Pakruojis d. mun.', '2015', '1575']
# ['Radviliškis d. mun.', '2014', '147']
# ['Radviliškis d. mun.', '2015', '173']
# ['Šiauliai c. mun.', '2014', '663']
# ['Šiauliai c. mun.', '2015', '709']
# ['Šiauliai d. mun.', '2014', '379']
# ['Šiauliai d. mun.', '2015', '408']
# ['Jurbarkas d. mun.', '2014', '48']
# ['Jurbarkas d. mun.', '2015', '48']
# ['Pagėgiai mun.', '2014', '25']
# ['Pagėgiai mun.', '2015', '10']
# ['Šilalė d. mun.', '2014', '6']
# ['Šilalė d. mun.', '2015', '5']
# ['Tauragė d. mun.', '2014', '487']
# ['Tauragė d. mun.', '2015', '565']
# ['Mažeikiai d. mun.', '2014', '5048']
# ['Mažeikiai d. mun.', '2015', '4454']
# ['Plungė d. mun.', '2014', '100']
# ['Plungė d. mun.', '2015', '460']
# ['Rietavas mun.', '2014', '1']
# ['Rietavas mun.', '2015', '1']
# ['Telšiai d. mun.', '2014', '76']
# ['Telšiai d. mun.', '2015', '81']
# ['Anykščiai d. mun.', '2014', '61']
# ['Anykščiai d. mun.', '2015', '366']
# ['Ignalina d. mun.', '2014', '214']
# ['Ignalina d. mun.', '2015', '225']
# ['Molėtai d. mun.', '2014', '61']
# ['Molėtai d. mun.', '2015', '101']
# ['Utena d. mun.', '2014', '5274']
# ['Utena d. mun.', '2015', '4144']
# ['Visaginas mun.', '2014', '476']
# ['Visaginas mun.', '2015', '387']
# ['Zarasai d. mun.', '2014', '60']
# ['Zarasai d. mun.', '2015', '60']
# ['Elektrėnai mun.', '2014', '3141']
# ['Elektrėnai mun.', '2015', '3660']
# ['Šalčininkai d. mun.', '2014', '3']
# ['Šalčininkai d. mun.', '2015', '16']
# ['Širvintos d. mun.', '2014', '41']
# ['Širvintos d. mun.', '2015', '75']
# ['Švenčionys d. mun.', '2014', '2157']
# ['Švenčionys d. mun.', '2015', '2300']
# ['Trakai d. mun.', '2014', '1507']
# ['Trakai d. mun.', '2015', '1609']
# ['Ukmergė d. mun.', '2014', '1224']
# ['Ukmergė d. mun.', '2015', '1538']
# ['Vilnius c. mun.', '2014', '15938']
# ['Vilnius c. mun.', '2015', '16729']
# ['Vilnius d. mun.', '2014', '2053']
# ['Vilnius d. mun.', '2015', '1888']

# %%
#add missing country values
for row_num in range(1,len(data)):
    data[row_num].append('Republic of Lithuania')
for row_num in range(0,len(data)):
    print (data[row_num])
# Out:
# ['\ufeff', '', 'Foreign direct investment per capita at the end of the year | EUR']
# ['Alytus t. mun.', '2014', '1219', 'Republic of Lithuania']
# ['Alytus t. mun.', '2015', '1376', 'Republic of Lithuania']
# ['Alytus d. mun.', '2014', '848', 'Republic of Lithuania']
# ['Alytus d. mun.', '2015', '969', 'Republic of Lithuania']
# ['Druskininkai mun.', '2014', '1256', 'Republic of Lithuania']
# ['Druskininkai mun.', '2015', '1725', 'Republic of Lithuania']
# ['Lazdijai d. mun.', '2014', '2', 'Republic of Lithuania']
# ['Lazdijai d. mun.', '2015', '4', 'Republic of Lithuania']
# ['Varėna d. mun.', '2014', '92', 'Republic of Lithuania']
# ['Varėna d. mun.', '2015', '65', 'Republic of Lithuania']
# ['Birštonas mun.', '2014', '48', 'Republic of Lithuania']
# ['Birštonas mun.', '2015', '60', 'Republic of Lithuania']
# ['Jonava d. mun.', '2014', '79', 'Republic of Lithuania']
# ['Jonava d. mun.', '2015', '140', 'Republic of Lithuania']
# ['Kaišiadorys d. mun.', '2014', '92', 'Republic of Lithuania']
# ['Kaišiadorys d. mun.', '2015', '142', 'Republic of Lithuania']
# ['Kaunas c. mun.', '2014', '3310', 'Republic of Lithuania']
# ['Kaunas c. mun.', '2015', '3446', 'Republic of Lithuania']
# ['Kaunas d. mun.', '2014', '1206', 'Republic of Lithuania']
# ['Kaunas d. mun.', '2015', '1279', 'Republic of Lithuania']
# ['Kėdainiai d. mun.', '2014', '5408', 'Republic of Lithuania']
# ['Kėdainiai d. mun.', '2015', '6573', 'Republic of Lithuania']
# ['Prienai d. mun.', '2014', '85', 'Republic of Lithuania']
# ['Prienai d. mun.', '2015', '109', 'Republic of Lithuania']
# ['Raseiniai d. mun.', '2014', '912', 'Republic of Lithuania']
# ['Raseiniai d. mun.', '2015', '903', 'Republic of Lithuania']
# ['Klaipėda c. mun.', '2014', '4457', 'Republic of Lithuania']
# ['Klaipėda c. mun.', '2015', '5578', 'Republic of Lithuania']
# ['Klaipėda d. mun.', '2014', '4666', 'Republic of Lithuania']
# ['Klaipėda d. mun.', '2015', '4815', 'Republic of Lithuania']
# ['Kretinga d. mun.', '2014', '200', 'Republic of Lithuania']
# ['Kretinga d. mun.', '2015', '256', 'Republic of Lithuania']
# ['Neringa mun.', '2014', '2501', 'Republic of Lithuania']
# ['Neringa mun.', '2015', '2609', 'Republic of Lithuania']
# ['Palanga t. mun.', '2014', '1958', 'Republic of Lithuania']
# ['Palanga t. mun.', '2015', '2101', 'Republic of Lithuania']
# ['Skuodas d. mun.', '2014', '128', 'Republic of Lithuania']
# ['Skuodas d. mun.', '2015', '137', 'Republic of Lithuania']
# ['Šilutė d. mun.', '2014', '588', 'Republic of Lithuania']
# ['Šilutė d. mun.', '2015', '981', 'Republic of Lithuania']
# ['Kalvarija mun.', '2014', '24', 'Republic of Lithuania']
# ['Kalvarija mun.', '2015', '36', 'Republic of Lithuania']
# ['Kazlų Rūda mun.', '2014', '7502', 'Republic of Lithuania']
# ['Kazlų Rūda mun.', '2015', '8077', 'Republic of Lithuania']
# ['Marijampolė mun.', '2014', '459', 'Republic of Lithuania']
# ['Marijampolė mun.', '2015', '410', 'Republic of Lithuania']
# ['Marijampolė d. mun.', '2014', '', 'Republic of Lithuania']
# ['Marijampolė d. mun.', '2015', '', 'Republic of Lithuania']
# ['Šakiai d. mun.', '2014', '469', 'Republic of Lithuania']
# ['Šakiai d. mun.', '2015', '457', 'Republic of Lithuania']
# ['Vilkaviškis d. mun.', '2014', '60', 'Republic of Lithuania']
# ['Vilkaviškis d. mun.', '2015', '85', 'Republic of Lithuania']
# ['Biržai d. mun.', '2014', '379', 'Republic of Lithuania']
# ['Biržai d. mun.', '2015', '903', 'Republic of Lithuania']
# ['Kupiškis d. mun.', '2014', '178', 'Republic of Lithuania']
# ['Kupiškis d. mun.', '2015', '183', 'Republic of Lithuania']
# ['Panevėžys c. mun.', '2014', '2446', 'Republic of Lithuania']
# ['Panevėžys c. mun.', '2015', '2614', 'Republic of Lithuania']
# ['Panevėžys d. mun.', '2014', '331', 'Republic of Lithuania']
# ['Panevėžys d. mun.', '2015', '661', 'Republic of Lithuania']
# ['Pasvalys d. mun.', '2014', '275', 'Republic of Lithuania']
# ['Pasvalys d. mun.', '2015', '308', 'Republic of Lithuania']
# ['Rokiškis d. mun.', '2014', '405', 'Republic of Lithuania']
# ['Rokiškis d. mun.', '2015', '421', 'Republic of Lithuania']
# ['Akmenė d. mun.', '2014', '2174', 'Republic of Lithuania']
# ['Akmenė d. mun.', '2015', '2247', 'Republic of Lithuania']
# ['Joniškis d. mun.', '2014', '22', 'Republic of Lithuania']
# ['Joniškis d. mun.', '2015', '31', 'Republic of Lithuania']
# ['Kelmė d. mun.', '2014', '8', 'Republic of Lithuania']
# ['Kelmė d. mun.', '2015', '6', 'Republic of Lithuania']
# ['Pakruojis d. mun.', '2014', '1498', 'Republic of Lithuania']
# ['Pakruojis d. mun.', '2015', '1575', 'Republic of Lithuania']
# ['Radviliškis d. mun.', '2014', '147', 'Republic of Lithuania']
# ['Radviliškis d. mun.', '2015', '173', 'Republic of Lithuania']
# ['Šiauliai c. mun.', '2014', '663', 'Republic of Lithuania']
# ['Šiauliai c. mun.', '2015', '709', 'Republic of Lithuania']
# ['Šiauliai d. mun.', '2014', '379', 'Republic of Lithuania']
# ['Šiauliai d. mun.', '2015', '408', 'Republic of Lithuania']
# ['Jurbarkas d. mun.', '2014', '48', 'Republic of Lithuania']
# ['Jurbarkas d. mun.', '2015', '48', 'Republic of Lithuania']
# ['Pagėgiai mun.', '2014', '25', 'Republic of Lithuania']
# ['Pagėgiai mun.', '2015', '10', 'Republic of Lithuania']
# ['Šilalė d. mun.', '2014', '6', 'Republic of Lithuania']
# ['Šilalė d. mun.', '2015', '5', 'Republic of Lithuania']
# ['Tauragė d. mun.', '2014', '487', 'Republic of Lithuania']
# ['Tauragė d. mun.', '2015', '565', 'Republic of Lithuania']
# ['Mažeikiai d. mun.', '2014', '5048', 'Republic of Lithuania']
# ['Mažeikiai d. mun.', '2015', '4454', 'Republic of Lithuania']
# ['Plungė d. mun.', '2014', '100', 'Republic of Lithuania']
# ['Plungė d. mun.', '2015', '460', 'Republic of Lithuania']
# ['Rietavas mun.', '2014', '1', 'Republic of Lithuania']
# ['Rietavas mun.', '2015', '1', 'Republic of Lithuania']
# ['Telšiai d. mun.', '2014', '76', 'Republic of Lithuania']
# ['Telšiai d. mun.', '2015', '81', 'Republic of Lithuania']
# ['Anykščiai d. mun.', '2014', '61', 'Republic of Lithuania']
# ['Anykščiai d. mun.', '2015', '366', 'Republic of Lithuania']
# ['Ignalina d. mun.', '2014', '214', 'Republic of Lithuania']
# ['Ignalina d. mun.', '2015', '225', 'Republic of Lithuania']
# ['Molėtai d. mun.', '2014', '61', 'Republic of Lithuania']
# ['Molėtai d. mun.', '2015', '101', 'Republic of Lithuania']
# ['Utena d. mun.', '2014', '5274', 'Republic of Lithuania']
# ['Utena d. mun.', '2015', '4144', 'Republic of Lithuania']
# ['Visaginas mun.', '2014', '476', 'Republic of Lithuania']
# ['Visaginas mun.', '2015', '387', 'Republic of Lithuania']
# ['Zarasai d. mun.', '2014', '60', 'Republic of Lithuania']
# ['Zarasai d. mun.', '2015', '60', 'Republic of Lithuania']
# ['Elektrėnai mun.', '2014', '3141', 'Republic of Lithuania']
# ['Elektrėnai mun.', '2015', '3660', 'Republic of Lithuania']
# ['Šalčininkai d. mun.', '2014', '3', 'Republic of Lithuania']
# ['Šalčininkai d. mun.', '2015', '16', 'Republic of Lithuania']
# ['Širvintos d. mun.', '2014', '41', 'Republic of Lithuania']
# ['Širvintos d. mun.', '2015', '75', 'Republic of Lithuania']
# ['Švenčionys d. mun.', '2014', '2157', 'Republic of Lithuania']
# ['Švenčionys d. mun.', '2015', '2300', 'Republic of Lithuania']
# ['Trakai d. mun.', '2014', '1507', 'Republic of Lithuania']
# ['Trakai d. mun.', '2015', '1609', 'Republic of Lithuania']
# ['Ukmergė d. mun.', '2014', '1224', 'Republic of Lithuania']
# ['Ukmergė d. mun.', '2015', '1538', 'Republic of Lithuania']
# ['Vilnius c. mun.', '2014', '15938', 'Republic of Lithuania']
# ['Vilnius c. mun.', '2015', '16729', 'Republic of Lithuania']
# ['Vilnius d. mun.', '2014', '2053', 'Republic of Lithuania']
# ['Vilnius d. mun.', '2015', '1888', 'Republic of Lithuania']

# %%
#add missing county values
chuncks=[0]
chunck=0

for row_num in range(1+chuncks[chunck],11+chuncks[chunck]):
        data[row_num].append('Alytus county')
for row_num in range(11+chuncks[chunck],27+chuncks[chunck]):
        data[row_num].append('Kaunas county')
for row_num in range(27+chuncks[chunck],41+chuncks[chunck]):
        data[row_num].append('Klaipeda county')
for row_num in range(41+chuncks[chunck],53+chuncks[chunck]):
        data[row_num].append('Marijampole county')
for row_num in range(53+chuncks[chunck],65+chuncks[chunck]):
        data[row_num].append('Panevezys county')
for row_num in range(65+chuncks[chunck],79+chuncks[chunck]):
        data[row_num].append('Siauliai county')
for row_num in range(79+chuncks[chunck],87+chuncks[chunck]):
        data[row_num].append('Taurage county')
for row_num in range(87+chuncks[chunck],95+chuncks[chunck]):
        data[row_num].append('Telsiai county')
for row_num in range(95+chuncks[chunck],107+chuncks[chunck]):
        data[row_num].append('Utena county')
for row_num in range(107+chuncks[chunck],123+chuncks[chunck]):
        data[row_num].append('Vilnius county')

        
for row_num in range(0,len(data)):
    print (data[row_num])
# Out:
# ['\ufeff', '', 'Foreign direct investment per capita at the end of the year | EUR']
# ['Alytus t. mun.', '2014', '1219', 'Republic of Lithuania', 'Alytus county']
# ['Alytus t. mun.', '2015', '1376', 'Republic of Lithuania', 'Alytus county']
# ['Alytus d. mun.', '2014', '848', 'Republic of Lithuania', 'Alytus county']
# ['Alytus d. mun.', '2015', '969', 'Republic of Lithuania', 'Alytus county']
# ['Druskininkai mun.', '2014', '1256', 'Republic of Lithuania', 'Alytus county']
# ['Druskininkai mun.', '2015', '1725', 'Republic of Lithuania', 'Alytus county']
# ['Lazdijai d. mun.', '2014', '2', 'Republic of Lithuania', 'Alytus county']
# ['Lazdijai d. mun.', '2015', '4', 'Republic of Lithuania', 'Alytus county']
# ['Varėna d. mun.', '2014', '92', 'Republic of Lithuania', 'Alytus county']
# ['Varėna d. mun.', '2015', '65', 'Republic of Lithuania', 'Alytus county']
# ['Birštonas mun.', '2014', '48', 'Republic of Lithuania', 'Kanuas county']
# ['Birštonas mun.', '2015', '60', 'Republic of Lithuania', 'Kanuas county']
# ['Jonava d. mun.', '2014', '79', 'Republic of Lithuania', 'Kanuas county']
# ['Jonava d. mun.', '2015', '140', 'Republic of Lithuania', 'Kanuas county']
# ['Kaišiadorys d. mun.', '2014', '92', 'Republic of Lithuania', 'Kanuas county']
# ['Kaišiadorys d. mun.', '2015', '142', 'Republic of Lithuania', 'Kanuas county']
# ['Kaunas c. mun.', '2014', '3310', 'Republic of Lithuania', 'Kanuas county']
# ['Kaunas c. mun.', '2015', '3446', 'Republic of Lithuania', 'Kanuas county']
# ['Kaunas d. mun.', '2014', '1206', 'Republic of Lithuania', 'Kanuas county']
# ['Kaunas d. mun.', '2015', '1279', 'Republic of Lithuania', 'Kanuas county']
# ['Kėdainiai d. mun.', '2014', '5408', 'Republic of Lithuania', 'Kanuas county']
# ['Kėdainiai d. mun.', '2015', '6573', 'Republic of Lithuania', 'Kanuas county']
# ['Prienai d. mun.', '2014', '85', 'Republic of Lithuania', 'Kanuas county']
# ['Prienai d. mun.', '2015', '109', 'Republic of Lithuania', 'Kanuas county']
# ['Raseiniai d. mun.', '2014', '912', 'Republic of Lithuania', 'Kanuas county']
# ['Raseiniai d. mun.', '2015', '903', 'Republic of Lithuania', 'Kanuas county']
# ['Klaipėda c. mun.', '2014', '4457', 'Republic of Lithuania', 'Klaipeda county']
# ['Klaipėda c. mun.', '2015', '5578', 'Republic of Lithuania', 'Klaipeda county']
# ['Klaipėda d. mun.', '2014', '4666', 'Republic of Lithuania', 'Klaipeda county']
# ['Klaipėda d. mun.', '2015', '4815', 'Republic of Lithuania', 'Klaipeda county']
# ['Kretinga d. mun.', '2014', '200', 'Republic of Lithuania', 'Klaipeda county']
# ['Kretinga d. mun.', '2015', '256', 'Republic of Lithuania', 'Klaipeda county']
# ['Neringa mun.', '2014', '2501', 'Republic of Lithuania', 'Klaipeda county']
# ['Neringa mun.', '2015', '2609', 'Republic of Lithuania', 'Klaipeda county']
# ['Palanga t. mun.', '2014', '1958', 'Republic of Lithuania', 'Klaipeda county']
# ['Palanga t. mun.', '2015', '2101', 'Republic of Lithuania', 'Klaipeda county']
# ['Skuodas d. mun.', '2014', '128', 'Republic of Lithuania', 'Klaipeda county']
# ['Skuodas d. mun.', '2015', '137', 'Republic of Lithuania', 'Klaipeda county']
# ['Šilutė d. mun.', '2014', '588', 'Republic of Lithuania', 'Klaipeda county']
# ['Šilutė d. mun.', '2015', '981', 'Republic of Lithuania', 'Klaipeda county']
# ['Kalvarija mun.', '2014', '24', 'Republic of Lithuania', 'Marijampole county']
# ['Kalvarija mun.', '2015', '36', 'Republic of Lithuania', 'Marijampole county']
# ['Kazlų Rūda mun.', '2014', '7502', 'Republic of Lithuania', 'Marijampole county']
# ['Kazlų Rūda mun.', '2015', '8077', 'Republic of Lithuania', 'Marijampole county']
# ['Marijampolė mun.', '2014', '459', 'Republic of Lithuania', 'Marijampole county']
# ['Marijampolė mun.', '2015', '410', 'Republic of Lithuania', 'Marijampole county']
# ['Marijampolė d. mun.', '2014', '', 'Republic of Lithuania', 'Marijampole county']
# ['Marijampolė d. mun.', '2015', '', 'Republic of Lithuania', 'Marijampole county']
# ['Šakiai d. mun.', '2014', '469', 'Republic of Lithuania', 'Marijampole county']
# ['Šakiai d. mun.', '2015', '457', 'Republic of Lithuania', 'Marijampole county']
# ['Vilkaviškis d. mun.', '2014', '60', 'Republic of Lithuania', 'Marijampole county']
# ['Vilkaviškis d. mun.', '2015', '85', 'Republic of Lithuania', 'Marijampole county']
# ['Biržai d. mun.', '2014', '379', 'Republic of Lithuania', 'Panevezys county']
# ['Biržai d. mun.', '2015', '903', 'Republic of Lithuania', 'Panevezys county']
# ['Kupiškis d. mun.', '2014', '178', 'Republic of Lithuania', 'Panevezys county']
# ['Kupiškis d. mun.', '2015', '183', 'Republic of Lithuania', 'Panevezys county']
# ['Panevėžys c. mun.', '2014', '2446', 'Republic of Lithuania', 'Panevezys county']
# ['Panevėžys c. mun.', '2015', '2614', 'Republic of Lithuania', 'Panevezys county']
# ['Panevėžys d. mun.', '2014', '331', 'Republic of Lithuania', 'Panevezys county']
# ['Panevėžys d. mun.', '2015', '661', 'Republic of Lithuania', 'Panevezys county']
# ['Pasvalys d. mun.', '2014', '275', 'Republic of Lithuania', 'Panevezys county']
# ['Pasvalys d. mun.', '2015', '308', 'Republic of Lithuania', 'Panevezys county']
# ['Rokiškis d. mun.', '2014', '405', 'Republic of Lithuania', 'Panevezys county']
# ['Rokiškis d. mun.', '2015', '421', 'Republic of Lithuania', 'Panevezys county']
# ['Akmenė d. mun.', '2014', '2174', 'Republic of Lithuania', 'Siauliai county']
# ['Akmenė d. mun.', '2015', '2247', 'Republic of Lithuania', 'Siauliai county']
# ['Joniškis d. mun.', '2014', '22', 'Republic of Lithuania', 'Siauliai county']
# ['Joniškis d. mun.', '2015', '31', 'Republic of Lithuania', 'Siauliai county']
# ['Kelmė d. mun.', '2014', '8', 'Republic of Lithuania', 'Siauliai county']
# ['Kelmė d. mun.', '2015', '6', 'Republic of Lithuania', 'Siauliai county']
# ['Pakruojis d. mun.', '2014', '1498', 'Republic of Lithuania', 'Siauliai county']
# ['Pakruojis d. mun.', '2015', '1575', 'Republic of Lithuania', 'Siauliai county']
# ['Radviliškis d. mun.', '2014', '147', 'Republic of Lithuania', 'Siauliai county']
# ['Radviliškis d. mun.', '2015', '173', 'Republic of Lithuania', 'Siauliai county']
# ['Šiauliai c. mun.', '2014', '663', 'Republic of Lithuania', 'Siauliai county']
# ['Šiauliai c. mun.', '2015', '709', 'Republic of Lithuania', 'Siauliai county']
# ['Šiauliai d. mun.', '2014', '379', 'Republic of Lithuania', 'Siauliai county']
# ['Šiauliai d. mun.', '2015', '408', 'Republic of Lithuania', 'Siauliai county']
# ['Jurbarkas d. mun.', '2014', '48', 'Republic of Lithuania', 'Taurage county']
# ['Jurbarkas d. mun.', '2015', '48', 'Republic of Lithuania', 'Taurage county']
# ['Pagėgiai mun.', '2014', '25', 'Republic of Lithuania', 'Taurage county']
# ['Pagėgiai mun.', '2015', '10', 'Republic of Lithuania', 'Taurage county']
# ['Šilalė d. mun.', '2014', '6', 'Republic of Lithuania', 'Taurage county']
# ['Šilalė d. mun.', '2015', '5', 'Republic of Lithuania', 'Taurage county']
# ['Tauragė d. mun.', '2014', '487', 'Republic of Lithuania', 'Taurage county']
# ['Tauragė d. mun.', '2015', '565', 'Republic of Lithuania', 'Taurage county']
# ['Mažeikiai d. mun.', '2014', '5048', 'Republic of Lithuania', 'Telsiai county']
# ['Mažeikiai d. mun.', '2015', '4454', 'Republic of Lithuania', 'Telsiai county']
# ['Plungė d. mun.', '2014', '100', 'Republic of Lithuania', 'Telsiai county']
# ['Plungė d. mun.', '2015', '460', 'Republic of Lithuania', 'Telsiai county']
# ['Rietavas mun.', '2014', '1', 'Republic of Lithuania', 'Telsiai county']
# ['Rietavas mun.', '2015', '1', 'Republic of Lithuania', 'Telsiai county']
# ['Telšiai d. mun.', '2014', '76', 'Republic of Lithuania', 'Telsiai county']
# ['Telšiai d. mun.', '2015', '81', 'Republic of Lithuania', 'Telsiai county']
# ['Anykščiai d. mun.', '2014', '61', 'Republic of Lithuania', 'Utena county']
# ['Anykščiai d. mun.', '2015', '366', 'Republic of Lithuania', 'Utena county']
# ['Ignalina d. mun.', '2014', '214', 'Republic of Lithuania', 'Utena county']
# ['Ignalina d. mun.', '2015', '225', 'Republic of Lithuania', 'Utena county']
# ['Molėtai d. mun.', '2014', '61', 'Republic of Lithuania', 'Utena county']
# ['Molėtai d. mun.', '2015', '101', 'Republic of Lithuania', 'Utena county']
# ['Utena d. mun.', '2014', '5274', 'Republic of Lithuania', 'Utena county']
# ['Utena d. mun.', '2015', '4144', 'Republic of Lithuania', 'Utena county']
# ['Visaginas mun.', '2014', '476', 'Republic of Lithuania', 'Utena county']
# ['Visaginas mun.', '2015', '387', 'Republic of Lithuania', 'Utena county']
# ['Zarasai d. mun.', '2014', '60', 'Republic of Lithuania', 'Utena county']
# ['Zarasai d. mun.', '2015', '60', 'Republic of Lithuania', 'Utena county']
# ['Elektrėnai mun.', '2014', '3141', 'Republic of Lithuania', 'Vilnius county']
# ['Elektrėnai mun.', '2015', '3660', 'Republic of Lithuania', 'Vilnius county']
# ['Šalčininkai d. mun.', '2014', '3', 'Republic of Lithuania', 'Vilnius county']
# ['Šalčininkai d. mun.', '2015', '16', 'Republic of Lithuania', 'Vilnius county']
# ['Širvintos d. mun.', '2014', '41', 'Republic of Lithuania', 'Vilnius county']
# ['Širvintos d. mun.', '2015', '75', 'Republic of Lithuania', 'Vilnius county']
# ['Švenčionys d. mun.', '2014', '2157', 'Republic of Lithuania', 'Vilnius county']
# ['Švenčionys d. mun.', '2015', '2300', 'Republic of Lithuania', 'Vilnius county']
# ['Trakai d. mun.', '2014', '1507', 'Republic of Lithuania', 'Vilnius county']
# ['Trakai d. mun.', '2015', '1609', 'Republic of Lithuania', 'Vilnius county']
# ['Ukmergė d. mun.', '2014', '1224', 'Republic of Lithuania', 'Vilnius county']
# ['Ukmergė d. mun.', '2015', '1538', 'Republic of Lithuania', 'Vilnius county']
# ['Vilnius c. mun.', '2014', '15938', 'Republic of Lithuania', 'Vilnius county']
# ['Vilnius c. mun.', '2015', '16729', 'Republic of Lithuania', 'Vilnius county']
# ['Vilnius d. mun.', '2014', '2053', 'Republic of Lithuania', 'Vilnius county']
# ['Vilnius d. mun.', '2015', '1888', 'Republic of Lithuania', 'Vilnius county']

# %%
#Adding collumn headers istead of the melformed header
headerList=['Municipality','Time_period','Foreign_direct_investment_per_capita_at_the_end_of_the_year_EUR','Country','County']
del data[0]
data.insert( 0, headerList)
for row_num in range(0,len(data)):
    print (data[row_num])
# Out:
# ['Municipality', 'Time_period', 'Foreign_direct_investment_per_capita_at_the_end_of_the_year_EUR', 'Country', 'County']
# ['Alytus t. mun.', '2014', '1219', 'Republic of Lithuania', 'Alytus county']
# ['Alytus t. mun.', '2015', '1376', 'Republic of Lithuania', 'Alytus county']
# ['Alytus d. mun.', '2014', '848', 'Republic of Lithuania', 'Alytus county']
# ['Alytus d. mun.', '2015', '969', 'Republic of Lithuania', 'Alytus county']
# ['Druskininkai mun.', '2014', '1256', 'Republic of Lithuania', 'Alytus county']
# ['Druskininkai mun.', '2015', '1725', 'Republic of Lithuania', 'Alytus county']
# ['Lazdijai d. mun.', '2014', '2', 'Republic of Lithuania', 'Alytus county']
# ['Lazdijai d. mun.', '2015', '4', 'Republic of Lithuania', 'Alytus county']
# ['Varėna d. mun.', '2014', '92', 'Republic of Lithuania', 'Alytus county']
# ['Varėna d. mun.', '2015', '65', 'Republic of Lithuania', 'Alytus county']
# ['Birštonas mun.', '2014', '48', 'Republic of Lithuania', 'Kanuas county']
# ['Birštonas mun.', '2015', '60', 'Republic of Lithuania', 'Kanuas county']
# ['Jonava d. mun.', '2014', '79', 'Republic of Lithuania', 'Kanuas county']
# ['Jonava d. mun.', '2015', '140', 'Republic of Lithuania', 'Kanuas county']
# ['Kaišiadorys d. mun.', '2014', '92', 'Republic of Lithuania', 'Kanuas county']
# ['Kaišiadorys d. mun.', '2015', '142', 'Republic of Lithuania', 'Kanuas county']
# ['Kaunas c. mun.', '2014', '3310', 'Republic of Lithuania', 'Kanuas county']
# ['Kaunas c. mun.', '2015', '3446', 'Republic of Lithuania', 'Kanuas county']
# ['Kaunas d. mun.', '2014', '1206', 'Republic of Lithuania', 'Kanuas county']
# ['Kaunas d. mun.', '2015', '1279', 'Republic of Lithuania', 'Kanuas county']
# ['Kėdainiai d. mun.', '2014', '5408', 'Republic of Lithuania', 'Kanuas county']
# ['Kėdainiai d. mun.', '2015', '6573', 'Republic of Lithuania', 'Kanuas county']
# ['Prienai d. mun.', '2014', '85', 'Republic of Lithuania', 'Kanuas county']
# ['Prienai d. mun.', '2015', '109', 'Republic of Lithuania', 'Kanuas county']
# ['Raseiniai d. mun.', '2014', '912', 'Republic of Lithuania', 'Kanuas county']
# ['Raseiniai d. mun.', '2015', '903', 'Republic of Lithuania', 'Kanuas county']
# ['Klaipėda c. mun.', '2014', '4457', 'Republic of Lithuania', 'Klaipeda county']
# ['Klaipėda c. mun.', '2015', '5578', 'Republic of Lithuania', 'Klaipeda county']
# ['Klaipėda d. mun.', '2014', '4666', 'Republic of Lithuania', 'Klaipeda county']
# ['Klaipėda d. mun.', '2015', '4815', 'Republic of Lithuania', 'Klaipeda county']
# ['Kretinga d. mun.', '2014', '200', 'Republic of Lithuania', 'Klaipeda county']
# ['Kretinga d. mun.', '2015', '256', 'Republic of Lithuania', 'Klaipeda county']
# ['Neringa mun.', '2014', '2501', 'Republic of Lithuania', 'Klaipeda county']
# ['Neringa mun.', '2015', '2609', 'Republic of Lithuania', 'Klaipeda county']
# ['Palanga t. mun.', '2014', '1958', 'Republic of Lithuania', 'Klaipeda county']
# ['Palanga t. mun.', '2015', '2101', 'Republic of Lithuania', 'Klaipeda county']
# ['Skuodas d. mun.', '2014', '128', 'Republic of Lithuania', 'Klaipeda county']
# ['Skuodas d. mun.', '2015', '137', 'Republic of Lithuania', 'Klaipeda county']
# ['Šilutė d. mun.', '2014', '588', 'Republic of Lithuania', 'Klaipeda county']
# ['Šilutė d. mun.', '2015', '981', 'Republic of Lithuania', 'Klaipeda county']
# ['Kalvarija mun.', '2014', '24', 'Republic of Lithuania', 'Marijampole county']
# ['Kalvarija mun.', '2015', '36', 'Republic of Lithuania', 'Marijampole county']
# ['Kazlų Rūda mun.', '2014', '7502', 'Republic of Lithuania', 'Marijampole county']
# ['Kazlų Rūda mun.', '2015', '8077', 'Republic of Lithuania', 'Marijampole county']
# ['Marijampolė mun.', '2014', '459', 'Republic of Lithuania', 'Marijampole county']
# ['Marijampolė mun.', '2015', '410', 'Republic of Lithuania', 'Marijampole county']
# ['Marijampolė d. mun.', '2014', '', 'Republic of Lithuania', 'Marijampole county']
# ['Marijampolė d. mun.', '2015', '', 'Republic of Lithuania', 'Marijampole county']
# ['Šakiai d. mun.', '2014', '469', 'Republic of Lithuania', 'Marijampole county']
# ['Šakiai d. mun.', '2015', '457', 'Republic of Lithuania', 'Marijampole county']
# ['Vilkaviškis d. mun.', '2014', '60', 'Republic of Lithuania', 'Marijampole county']
# ['Vilkaviškis d. mun.', '2015', '85', 'Republic of Lithuania', 'Marijampole county']
# ['Biržai d. mun.', '2014', '379', 'Republic of Lithuania', 'Panevezys county']
# ['Biržai d. mun.', '2015', '903', 'Republic of Lithuania', 'Panevezys county']
# ['Kupiškis d. mun.', '2014', '178', 'Republic of Lithuania', 'Panevezys county']
# ['Kupiškis d. mun.', '2015', '183', 'Republic of Lithuania', 'Panevezys county']
# ['Panevėžys c. mun.', '2014', '2446', 'Republic of Lithuania', 'Panevezys county']
# ['Panevėžys c. mun.', '2015', '2614', 'Republic of Lithuania', 'Panevezys county']
# ['Panevėžys d. mun.', '2014', '331', 'Republic of Lithuania', 'Panevezys county']
# ['Panevėžys d. mun.', '2015', '661', 'Republic of Lithuania', 'Panevezys county']
# ['Pasvalys d. mun.', '2014', '275', 'Republic of Lithuania', 'Panevezys county']
# ['Pasvalys d. mun.', '2015', '308', 'Republic of Lithuania', 'Panevezys county']
# ['Rokiškis d. mun.', '2014', '405', 'Republic of Lithuania', 'Panevezys county']
# ['Rokiškis d. mun.', '2015', '421', 'Republic of Lithuania', 'Panevezys county']
# ['Akmenė d. mun.', '2014', '2174', 'Republic of Lithuania', 'Siauliai county']
# ['Akmenė d. mun.', '2015', '2247', 'Republic of Lithuania', 'Siauliai county']
# ['Joniškis d. mun.', '2014', '22', 'Republic of Lithuania', 'Siauliai county']
# ['Joniškis d. mun.', '2015', '31', 'Republic of Lithuania', 'Siauliai county']
# ['Kelmė d. mun.', '2014', '8', 'Republic of Lithuania', 'Siauliai county']
# ['Kelmė d. mun.', '2015', '6', 'Republic of Lithuania', 'Siauliai county']
# ['Pakruojis d. mun.', '2014', '1498', 'Republic of Lithuania', 'Siauliai county']
# ['Pakruojis d. mun.', '2015', '1575', 'Republic of Lithuania', 'Siauliai county']
# ['Radviliškis d. mun.', '2014', '147', 'Republic of Lithuania', 'Siauliai county']
# ['Radviliškis d. mun.', '2015', '173', 'Republic of Lithuania', 'Siauliai county']
# ['Šiauliai c. mun.', '2014', '663', 'Republic of Lithuania', 'Siauliai county']
# ['Šiauliai c. mun.', '2015', '709', 'Republic of Lithuania', 'Siauliai county']
# ['Šiauliai d. mun.', '2014', '379', 'Republic of Lithuania', 'Siauliai county']
# ['Šiauliai d. mun.', '2015', '408', 'Republic of Lithuania', 'Siauliai county']
# ['Jurbarkas d. mun.', '2014', '48', 'Republic of Lithuania', 'Taurage county']
# ['Jurbarkas d. mun.', '2015', '48', 'Republic of Lithuania', 'Taurage county']
# ['Pagėgiai mun.', '2014', '25', 'Republic of Lithuania', 'Taurage county']
# ['Pagėgiai mun.', '2015', '10', 'Republic of Lithuania', 'Taurage county']
# ['Šilalė d. mun.', '2014', '6', 'Republic of Lithuania', 'Taurage county']
# ['Šilalė d. mun.', '2015', '5', 'Republic of Lithuania', 'Taurage county']
# ['Tauragė d. mun.', '2014', '487', 'Republic of Lithuania', 'Taurage county']
# ['Tauragė d. mun.', '2015', '565', 'Republic of Lithuania', 'Taurage county']
# ['Mažeikiai d. mun.', '2014', '5048', 'Republic of Lithuania', 'Telsiai county']
# ['Mažeikiai d. mun.', '2015', '4454', 'Republic of Lithuania', 'Telsiai county']
# ['Plungė d. mun.', '2014', '100', 'Republic of Lithuania', 'Telsiai county']
# ['Plungė d. mun.', '2015', '460', 'Republic of Lithuania', 'Telsiai county']
# ['Rietavas mun.', '2014', '1', 'Republic of Lithuania', 'Telsiai county']
# ['Rietavas mun.', '2015', '1', 'Republic of Lithuania', 'Telsiai county']
# ['Telšiai d. mun.', '2014', '76', 'Republic of Lithuania', 'Telsiai county']
# ['Telšiai d. mun.', '2015', '81', 'Republic of Lithuania', 'Telsiai county']
# ['Anykščiai d. mun.', '2014', '61', 'Republic of Lithuania', 'Utena county']
# ['Anykščiai d. mun.', '2015', '366', 'Republic of Lithuania', 'Utena county']
# ['Ignalina d. mun.', '2014', '214', 'Republic of Lithuania', 'Utena county']
# ['Ignalina d. mun.', '2015', '225', 'Republic of Lithuania', 'Utena county']
# ['Molėtai d. mun.', '2014', '61', 'Republic of Lithuania', 'Utena county']
# ['Molėtai d. mun.', '2015', '101', 'Republic of Lithuania', 'Utena county']
# ['Utena d. mun.', '2014', '5274', 'Republic of Lithuania', 'Utena county']
# ['Utena d. mun.', '2015', '4144', 'Republic of Lithuania', 'Utena county']
# ['Visaginas mun.', '2014', '476', 'Republic of Lithuania', 'Utena county']
# ['Visaginas mun.', '2015', '387', 'Republic of Lithuania', 'Utena county']
# ['Zarasai d. mun.', '2014', '60', 'Republic of Lithuania', 'Utena county']
# ['Zarasai d. mun.', '2015', '60', 'Republic of Lithuania', 'Utena county']
# ['Elektrėnai mun.', '2014', '3141', 'Republic of Lithuania', 'Vilnius county']
# ['Elektrėnai mun.', '2015', '3660', 'Republic of Lithuania', 'Vilnius county']
# ['Šalčininkai d. mun.', '2014', '3', 'Republic of Lithuania', 'Vilnius county']
# ['Šalčininkai d. mun.', '2015', '16', 'Republic of Lithuania', 'Vilnius county']
# ['Širvintos d. mun.', '2014', '41', 'Republic of Lithuania', 'Vilnius county']
# ['Širvintos d. mun.', '2015', '75', 'Republic of Lithuania', 'Vilnius county']
# ['Švenčionys d. mun.', '2014', '2157', 'Republic of Lithuania', 'Vilnius county']
# ['Švenčionys d. mun.', '2015', '2300', 'Republic of Lithuania', 'Vilnius county']
# ['Trakai d. mun.', '2014', '1507', 'Republic of Lithuania', 'Vilnius county']
# ['Trakai d. mun.', '2015', '1609', 'Republic of Lithuania', 'Vilnius county']
# ['Ukmergė d. mun.', '2014', '1224', 'Republic of Lithuania', 'Vilnius county']
# ['Ukmergė d. mun.', '2015', '1538', 'Republic of Lithuania', 'Vilnius county']
# ['Vilnius c. mun.', '2014', '15938', 'Republic of Lithuania', 'Vilnius county']
# ['Vilnius c. mun.', '2015', '16729', 'Republic of Lithuania', 'Vilnius county']
# ['Vilnius d. mun.', '2014', '2053', 'Republic of Lithuania', 'Vilnius county']
# ['Vilnius d. mun.', '2015', '1888', 'Republic of Lithuania', 'Vilnius county']

# %%
import csv
#print (data)
with open("Ready_datasets/readyDataSet5.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(data)
