# %% [markdown]
# <h3>Data set #6:<br>
# Investment in tangible fixed assets at current prices (2015) <br>
# http://osp.stat.gov.lt/en/statistiniu-rodikliu-analize?portletFormName=visualization&hash=061b4c9b-03d7-4303-84b0-2a39bc730e00</h3>

# %%
#pulling csv data from file
import csv
filename='Source_datasets/Exported matrix table_d6.csv'
with open(filename, 'r') as f:
    data = list(csv.reader(f))
#print (data)
#print (f)
for row_num in range(0,len(data)):
    print (data[row_num])
# Out:
# ['\ufeff', '', 'Investment in tangible fixed assets at current prices | EUR thousand']
# ['Republic of Lithuania', '2015', '5869198']
# ['Alytus county', '2015', '261318']
# ['Alytus t. mun.', '2015', '60726']
# ['Alytus d. mun.', '2015', '144157']
# ['Druskininkai mun.', '2015', '31103']
# ['Lazdijai d. mun.', '2015', '8072']
# ['Varėna d. mun.', '2015', '17260']
# ['Kaunas county', '2015', '1047899']
# ['Birštonas mun.', '2015', '6095']
# ['Jonava d. mun.', '2015', '84388']
# ['Kaišiadorys d. mun.', '2015', '35612']
# ['Kaunas c. mun.', '2015', '614537']
# ['Kaunas d. mun.', '2015', '198011']
# ['Kėdainiai d. mun.', '2015', '71893']
# ['Prienai d. mun.', '2015', '14409']
# ['Raseiniai d. mun.', '2015', '22954']
# ['Klaipėda county', '2015', '913203']
# ['Klaipėda c. mun.', '2015', '483394']
# ['Klaipėda d. mun.', '2015', '283588']
# ['Kretinga d. mun.', '2015', '36191']
# ['Neringa mun.', '2015', '12044']
# ['Palanga t. mun.', '2015', '48346']
# ['Skuodas d. mun.', '2015', '6824']
# ['Šilutė d. mun.', '2015', '42816']
# ['Marijampolė county', '2015', '165164']
# ['Kalvarija mun.', '2015', '9378']
# ['Kazlų Rūda mun.', '2015', '11172']
# ['Marijampolė mun.', '2015', '97519']
# ['Marijampolė d. mun.', '2015', '']
# ['Šakiai d. mun.', '2015', '25717']
# ['Vilkaviškis d. mun.', '2015', '21378']
# ['Panevėžys county', '2015', '235856']
# ['Biržai d. mun.', '2015', '15418']
# ['Kupiškis d. mun.', '2015', '13551']
# ['Panevėžys c. mun.', '2015', '123142']
# ['Panevėžys d. mun.', '2015', '37861']
# ['Pasvalys d. mun.', '2015', '21101']
# ['Rokiškis d. mun.', '2015', '24783']
# ['Šiauliai county', '2015', '388415']
# ['Akmenė d. mun.', '2015', '18471']
# ['Joniškis d. mun.', '2015', '20784']
# ['Kelmė d. mun.', '2015', '12555']
# ['Pakruojis d. mun.', '2015', '24957']
# ['Radviliškis d. mun.', '2015', '27713']
# ['Šiauliai c. mun.', '2015', '212544']
# ['Šiauliai d. mun.', '2015', '71391']
# ['Tauragė county', '2015', '80344']
# ['Jurbarkas d. mun.', '2015', '20444']
# ['Pagėgiai mun.', '2015', '5971']
# ['Šilalė d. mun.', '2015', '12835']
# ['Tauragė d. mun.', '2015', '41094']
# ['Telšiai county', '2015', '181007']
# ['Mažeikiai d. mun.', '2015', '76549']
# ['Plungė d. mun.', '2015', '46127']
# ['Rietavas mun.', '2015', '8867']
# ['Telšiai d. mun.', '2015', '49464']
# ['Utena county', '2015', '172385']
# ['Anykščiai d. mun.', '2015', '12423']
# ['Ignalina d. mun.', '2015', '12939']
# ['Molėtai d. mun.', '2015', '14090']
# ['Utena d. mun.', '2015', '70873']
# ['Visaginas mun.', '2015', '53313']
# ['Zarasai d. mun.', '2015', '8747']
# ['Vilnius county', '2015', '2196270']
# ['Elektrėnai mun.', '2015', '48720']
# ['Šalčininkai d. mun.', '2015', '16442']
# ['Širvintos d. mun.', '2015', '10150']
# ['Švenčionys d. mun.', '2015', '27117']
# ['Trakai d. mun.', '2015', '62381']
# ['Ukmergė d. mun.', '2015', '28490']
# ['Vilnius c. mun.', '2015', '1810179']
# ['Vilnius d. mun.', '2015', '192791']

# %%
#remove aggregated rows, as aggregation will take place later e.g. in pivotjs
keysList=['Republic','county']
tobedeletedList=[]

updated_lengh=len(data)
for row_num in range(0,updated_lengh):
    for key in keysList:
        #print (key)
        if key in data[row_num][0]:
            tobedeletedList.append(row_num)
            #tobedeletedList.append(row_num+1)#for 2015 rows

print (tobedeletedList)

for aggregated_row_num in tobedeletedList:
    #print (data[aggregated_row_num])
    data[aggregated_row_num]=['']
    #tobedeletedList[:] = [x - 1 for x in tobedeletedList]
   #print (tobedeletedList)
    
for row_num in range(0,len(data)):
    print (data[row_num])
# Out:
# [1, 2, 8, 17, 25, 32, 39, 47, 52, 57, 64]
# ['\ufeff', '', 'Investment in tangible fixed assets at current prices | EUR thousand']
# ['']
# ['']
# ['Alytus t. mun.', '2015', '60726']
# ['Alytus d. mun.', '2015', '144157']
# ['Druskininkai mun.', '2015', '31103']
# ['Lazdijai d. mun.', '2015', '8072']
# ['Varėna d. mun.', '2015', '17260']
# ['']
# ['Birštonas mun.', '2015', '6095']
# ['Jonava d. mun.', '2015', '84388']
# ['Kaišiadorys d. mun.', '2015', '35612']
# ['Kaunas c. mun.', '2015', '614537']
# ['Kaunas d. mun.', '2015', '198011']
# ['Kėdainiai d. mun.', '2015', '71893']
# ['Prienai d. mun.', '2015', '14409']
# ['Raseiniai d. mun.', '2015', '22954']
# ['']
# ['Klaipėda c. mun.', '2015', '483394']
# ['Klaipėda d. mun.', '2015', '283588']
# ['Kretinga d. mun.', '2015', '36191']
# ['Neringa mun.', '2015', '12044']
# ['Palanga t. mun.', '2015', '48346']
# ['Skuodas d. mun.', '2015', '6824']
# ['Šilutė d. mun.', '2015', '42816']
# ['']
# ['Kalvarija mun.', '2015', '9378']
# ['Kazlų Rūda mun.', '2015', '11172']
# ['Marijampolė mun.', '2015', '97519']
# ['Marijampolė d. mun.', '2015', '']
# ['Šakiai d. mun.', '2015', '25717']
# ['Vilkaviškis d. mun.', '2015', '21378']
# ['']
# ['Biržai d. mun.', '2015', '15418']
# ['Kupiškis d. mun.', '2015', '13551']
# ['Panevėžys c. mun.', '2015', '123142']
# ['Panevėžys d. mun.', '2015', '37861']
# ['Pasvalys d. mun.', '2015', '21101']
# ['Rokiškis d. mun.', '2015', '24783']
# ['']
# ['Akmenė d. mun.', '2015', '18471']
# ['Joniškis d. mun.', '2015', '20784']
# ['Kelmė d. mun.', '2015', '12555']
# ['Pakruojis d. mun.', '2015', '24957']
# ['Radviliškis d. mun.', '2015', '27713']
# ['Šiauliai c. mun.', '2015', '212544']
# ['Šiauliai d. mun.', '2015', '71391']
# ['']
# ['Jurbarkas d. mun.', '2015', '20444']
# ['Pagėgiai mun.', '2015', '5971']
# ['Šilalė d. mun.', '2015', '12835']
# ['Tauragė d. mun.', '2015', '41094']
# ['']
# ['Mažeikiai d. mun.', '2015', '76549']
# ['Plungė d. mun.', '2015', '46127']
# ['Rietavas mun.', '2015', '8867']
# ['Telšiai d. mun.', '2015', '49464']
# ['']
# ['Anykščiai d. mun.', '2015', '12423']
# ['Ignalina d. mun.', '2015', '12939']
# ['Molėtai d. mun.', '2015', '14090']
# ['Utena d. mun.', '2015', '70873']
# ['Visaginas mun.', '2015', '53313']
# ['Zarasai d. mun.', '2015', '8747']
# ['']
# ['Elektrėnai mun.', '2015', '48720']
# ['Šalčininkai d. mun.', '2015', '16442']
# ['Širvintos d. mun.', '2015', '10150']
# ['Švenčionys d. mun.', '2015', '27117']
# ['Trakai d. mun.', '2015', '62381']
# ['Ukmergė d. mun.', '2015', '28490']
# ['Vilnius c. mun.', '2015', '1810179']
# ['Vilnius d. mun.', '2015', '192791']

# %%
#permanent clean of unwanted rows in dataset
tobedeletedList=[]
for row_num in range (1,len(data)):
    if (len(data[row_num])<3):#regarding temporary header size
        #print ("row num{}:{}".format(i,data[row_num]))
        tobedeletedList.append(row_num)
print (tobedeletedList)
for aggregated_row_num in tobedeletedList:
    #print (data[aggregated_row_num])
    del data[aggregated_row_num]
    tobedeletedList[:] = [x - 1 for x in tobedeletedList]
   #print (tobedeletedList)
    
for row_num in range(0,len(data)):
    print (data[row_num])
# Out:
# [1, 2, 8, 17, 25, 32, 39, 47, 52, 57, 64]
# ['\ufeff', '', 'Investment in tangible fixed assets at current prices | EUR thousand']
# ['Alytus t. mun.', '2015', '60726']
# ['Alytus d. mun.', '2015', '144157']
# ['Druskininkai mun.', '2015', '31103']
# ['Lazdijai d. mun.', '2015', '8072']
# ['Varėna d. mun.', '2015', '17260']
# ['Birštonas mun.', '2015', '6095']
# ['Jonava d. mun.', '2015', '84388']
# ['Kaišiadorys d. mun.', '2015', '35612']
# ['Kaunas c. mun.', '2015', '614537']
# ['Kaunas d. mun.', '2015', '198011']
# ['Kėdainiai d. mun.', '2015', '71893']
# ['Prienai d. mun.', '2015', '14409']
# ['Raseiniai d. mun.', '2015', '22954']
# ['Klaipėda c. mun.', '2015', '483394']
# ['Klaipėda d. mun.', '2015', '283588']
# ['Kretinga d. mun.', '2015', '36191']
# ['Neringa mun.', '2015', '12044']
# ['Palanga t. mun.', '2015', '48346']
# ['Skuodas d. mun.', '2015', '6824']
# ['Šilutė d. mun.', '2015', '42816']
# ['Kalvarija mun.', '2015', '9378']
# ['Kazlų Rūda mun.', '2015', '11172']
# ['Marijampolė mun.', '2015', '97519']
# ['Marijampolė d. mun.', '2015', '']
# ['Šakiai d. mun.', '2015', '25717']
# ['Vilkaviškis d. mun.', '2015', '21378']
# ['Biržai d. mun.', '2015', '15418']
# ['Kupiškis d. mun.', '2015', '13551']
# ['Panevėžys c. mun.', '2015', '123142']
# ['Panevėžys d. mun.', '2015', '37861']
# ['Pasvalys d. mun.', '2015', '21101']
# ['Rokiškis d. mun.', '2015', '24783']
# ['Akmenė d. mun.', '2015', '18471']
# ['Joniškis d. mun.', '2015', '20784']
# ['Kelmė d. mun.', '2015', '12555']
# ['Pakruojis d. mun.', '2015', '24957']
# ['Radviliškis d. mun.', '2015', '27713']
# ['Šiauliai c. mun.', '2015', '212544']
# ['Šiauliai d. mun.', '2015', '71391']
# ['Jurbarkas d. mun.', '2015', '20444']
# ['Pagėgiai mun.', '2015', '5971']
# ['Šilalė d. mun.', '2015', '12835']
# ['Tauragė d. mun.', '2015', '41094']
# ['Mažeikiai d. mun.', '2015', '76549']
# ['Plungė d. mun.', '2015', '46127']
# ['Rietavas mun.', '2015', '8867']
# ['Telšiai d. mun.', '2015', '49464']
# ['Anykščiai d. mun.', '2015', '12423']
# ['Ignalina d. mun.', '2015', '12939']
# ['Molėtai d. mun.', '2015', '14090']
# ['Utena d. mun.', '2015', '70873']
# ['Visaginas mun.', '2015', '53313']
# ['Zarasai d. mun.', '2015', '8747']
# ['Elektrėnai mun.', '2015', '48720']
# ['Šalčininkai d. mun.', '2015', '16442']
# ['Širvintos d. mun.', '2015', '10150']
# ['Švenčionys d. mun.', '2015', '27117']
# ['Trakai d. mun.', '2015', '62381']
# ['Ukmergė d. mun.', '2015', '28490']
# ['Vilnius c. mun.', '2015', '1810179']
# ['Vilnius d. mun.', '2015', '192791']

# %%
#add missing country values
for row_num in range(1,len(data)):
    data[row_num].append('Republic of Lithuania')
for row_num in range(0,len(data)):
    print (data[row_num])
# Out:
# ['\ufeff', '', 'Investment in tangible fixed assets at current prices | EUR thousand']
# ['Alytus t. mun.', '2015', '60726', 'Republic of Lithuania']
# ['Alytus d. mun.', '2015', '144157', 'Republic of Lithuania']
# ['Druskininkai mun.', '2015', '31103', 'Republic of Lithuania']
# ['Lazdijai d. mun.', '2015', '8072', 'Republic of Lithuania']
# ['Varėna d. mun.', '2015', '17260', 'Republic of Lithuania']
# ['Birštonas mun.', '2015', '6095', 'Republic of Lithuania']
# ['Jonava d. mun.', '2015', '84388', 'Republic of Lithuania']
# ['Kaišiadorys d. mun.', '2015', '35612', 'Republic of Lithuania']
# ['Kaunas c. mun.', '2015', '614537', 'Republic of Lithuania']
# ['Kaunas d. mun.', '2015', '198011', 'Republic of Lithuania']
# ['Kėdainiai d. mun.', '2015', '71893', 'Republic of Lithuania']
# ['Prienai d. mun.', '2015', '14409', 'Republic of Lithuania']
# ['Raseiniai d. mun.', '2015', '22954', 'Republic of Lithuania']
# ['Klaipėda c. mun.', '2015', '483394', 'Republic of Lithuania']
# ['Klaipėda d. mun.', '2015', '283588', 'Republic of Lithuania']
# ['Kretinga d. mun.', '2015', '36191', 'Republic of Lithuania']
# ['Neringa mun.', '2015', '12044', 'Republic of Lithuania']
# ['Palanga t. mun.', '2015', '48346', 'Republic of Lithuania']
# ['Skuodas d. mun.', '2015', '6824', 'Republic of Lithuania']
# ['Šilutė d. mun.', '2015', '42816', 'Republic of Lithuania']
# ['Kalvarija mun.', '2015', '9378', 'Republic of Lithuania']
# ['Kazlų Rūda mun.', '2015', '11172', 'Republic of Lithuania']
# ['Marijampolė mun.', '2015', '97519', 'Republic of Lithuania']
# ['Marijampolė d. mun.', '2015', '', 'Republic of Lithuania']
# ['Šakiai d. mun.', '2015', '25717', 'Republic of Lithuania']
# ['Vilkaviškis d. mun.', '2015', '21378', 'Republic of Lithuania']
# ['Biržai d. mun.', '2015', '15418', 'Republic of Lithuania']
# ['Kupiškis d. mun.', '2015', '13551', 'Republic of Lithuania']
# ['Panevėžys c. mun.', '2015', '123142', 'Republic of Lithuania']
# ['Panevėžys d. mun.', '2015', '37861', 'Republic of Lithuania']
# ['Pasvalys d. mun.', '2015', '21101', 'Republic of Lithuania']
# ['Rokiškis d. mun.', '2015', '24783', 'Republic of Lithuania']
# ['Akmenė d. mun.', '2015', '18471', 'Republic of Lithuania']
# ['Joniškis d. mun.', '2015', '20784', 'Republic of Lithuania']
# ['Kelmė d. mun.', '2015', '12555', 'Republic of Lithuania']
# ['Pakruojis d. mun.', '2015', '24957', 'Republic of Lithuania']
# ['Radviliškis d. mun.', '2015', '27713', 'Republic of Lithuania']
# ['Šiauliai c. mun.', '2015', '212544', 'Republic of Lithuania']
# ['Šiauliai d. mun.', '2015', '71391', 'Republic of Lithuania']
# ['Jurbarkas d. mun.', '2015', '20444', 'Republic of Lithuania']
# ['Pagėgiai mun.', '2015', '5971', 'Republic of Lithuania']
# ['Šilalė d. mun.', '2015', '12835', 'Republic of Lithuania']
# ['Tauragė d. mun.', '2015', '41094', 'Republic of Lithuania']
# ['Mažeikiai d. mun.', '2015', '76549', 'Republic of Lithuania']
# ['Plungė d. mun.', '2015', '46127', 'Republic of Lithuania']
# ['Rietavas mun.', '2015', '8867', 'Republic of Lithuania']
# ['Telšiai d. mun.', '2015', '49464', 'Republic of Lithuania']
# ['Anykščiai d. mun.', '2015', '12423', 'Republic of Lithuania']
# ['Ignalina d. mun.', '2015', '12939', 'Republic of Lithuania']
# ['Molėtai d. mun.', '2015', '14090', 'Republic of Lithuania']
# ['Utena d. mun.', '2015', '70873', 'Republic of Lithuania']
# ['Visaginas mun.', '2015', '53313', 'Republic of Lithuania']
# ['Zarasai d. mun.', '2015', '8747', 'Republic of Lithuania']
# ['Elektrėnai mun.', '2015', '48720', 'Republic of Lithuania']
# ['Šalčininkai d. mun.', '2015', '16442', 'Republic of Lithuania']
# ['Širvintos d. mun.', '2015', '10150', 'Republic of Lithuania']
# ['Švenčionys d. mun.', '2015', '27117', 'Republic of Lithuania']
# ['Trakai d. mun.', '2015', '62381', 'Republic of Lithuania']
# ['Ukmergė d. mun.', '2015', '28490', 'Republic of Lithuania']
# ['Vilnius c. mun.', '2015', '1810179', 'Republic of Lithuania']
# ['Vilnius d. mun.', '2015', '192791', 'Republic of Lithuania']

# %%
#add missing county values
for row_num in range(1,6):
        data[row_num].append('Alytus county')
for row_num in range(6,14):
        data[row_num].append('Kaunas county')
for row_num in range(14,21):
        data[row_num].append('Klaipeda county')
for row_num in range(21,27):
        data[row_num].append('Marijampole county')
for row_num in range(27,33):
        data[row_num].append('Panevezys county')
for row_num in range(33,40):
        data[row_num].append('Siauliai county')
for row_num in range(40,44):
        data[row_num].append('Taurage county')
for row_num in range(44,48):
        data[row_num].append('Telsiai county')
for row_num in range(48,54):
        data[row_num].append('Utena county')
for row_num in range(54,62):
        data[row_num].append('Vilnius county')

        
for row_num in range(0,len(data)):
    print (data[row_num])
# Out:
# ['\ufeff', '', 'Investment in tangible fixed assets at current prices | EUR thousand']
# ['Alytus t. mun.', '2015', '60726', 'Republic of Lithuania', 'Alytus county']
# ['Alytus d. mun.', '2015', '144157', 'Republic of Lithuania', 'Alytus county']
# ['Druskininkai mun.', '2015', '31103', 'Republic of Lithuania', 'Alytus county']
# ['Lazdijai d. mun.', '2015', '8072', 'Republic of Lithuania', 'Alytus county']
# ['Varėna d. mun.', '2015', '17260', 'Republic of Lithuania', 'Alytus county']
# ['Birštonas mun.', '2015', '6095', 'Republic of Lithuania', 'Kanuas county']
# ['Jonava d. mun.', '2015', '84388', 'Republic of Lithuania', 'Kanuas county']
# ['Kaišiadorys d. mun.', '2015', '35612', 'Republic of Lithuania', 'Kanuas county']
# ['Kaunas c. mun.', '2015', '614537', 'Republic of Lithuania', 'Kanuas county']
# ['Kaunas d. mun.', '2015', '198011', 'Republic of Lithuania', 'Kanuas county']
# ['Kėdainiai d. mun.', '2015', '71893', 'Republic of Lithuania', 'Kanuas county']
# ['Prienai d. mun.', '2015', '14409', 'Republic of Lithuania', 'Kanuas county']
# ['Raseiniai d. mun.', '2015', '22954', 'Republic of Lithuania', 'Kanuas county']
# ['Klaipėda c. mun.', '2015', '483394', 'Republic of Lithuania', 'Klaipeda county']
# ['Klaipėda d. mun.', '2015', '283588', 'Republic of Lithuania', 'Klaipeda county']
# ['Kretinga d. mun.', '2015', '36191', 'Republic of Lithuania', 'Klaipeda county']
# ['Neringa mun.', '2015', '12044', 'Republic of Lithuania', 'Klaipeda county']
# ['Palanga t. mun.', '2015', '48346', 'Republic of Lithuania', 'Klaipeda county']
# ['Skuodas d. mun.', '2015', '6824', 'Republic of Lithuania', 'Klaipeda county']
# ['Šilutė d. mun.', '2015', '42816', 'Republic of Lithuania', 'Klaipeda county']
# ['Kalvarija mun.', '2015', '9378', 'Republic of Lithuania', 'Marijampole county']
# ['Kazlų Rūda mun.', '2015', '11172', 'Republic of Lithuania', 'Marijampole county']
# ['Marijampolė mun.', '2015', '97519', 'Republic of Lithuania', 'Marijampole county']
# ['Marijampolė d. mun.', '2015', '', 'Republic of Lithuania', 'Marijampole county']
# ['Šakiai d. mun.', '2015', '25717', 'Republic of Lithuania', 'Marijampole county']
# ['Vilkaviškis d. mun.', '2015', '21378', 'Republic of Lithuania', 'Marijampole county']
# ['Biržai d. mun.', '2015', '15418', 'Republic of Lithuania', 'Panevezys county']
# ['Kupiškis d. mun.', '2015', '13551', 'Republic of Lithuania', 'Panevezys county']
# ['Panevėžys c. mun.', '2015', '123142', 'Republic of Lithuania', 'Panevezys county']
# ['Panevėžys d. mun.', '2015', '37861', 'Republic of Lithuania', 'Panevezys county']
# ['Pasvalys d. mun.', '2015', '21101', 'Republic of Lithuania', 'Panevezys county']
# ['Rokiškis d. mun.', '2015', '24783', 'Republic of Lithuania', 'Panevezys county']
# ['Akmenė d. mun.', '2015', '18471', 'Republic of Lithuania', 'Siauliai county']
# ['Joniškis d. mun.', '2015', '20784', 'Republic of Lithuania', 'Siauliai county']
# ['Kelmė d. mun.', '2015', '12555', 'Republic of Lithuania', 'Siauliai county']
# ['Pakruojis d. mun.', '2015', '24957', 'Republic of Lithuania', 'Siauliai county']
# ['Radviliškis d. mun.', '2015', '27713', 'Republic of Lithuania', 'Siauliai county']
# ['Šiauliai c. mun.', '2015', '212544', 'Republic of Lithuania', 'Siauliai county']
# ['Šiauliai d. mun.', '2015', '71391', 'Republic of Lithuania', 'Siauliai county']
# ['Jurbarkas d. mun.', '2015', '20444', 'Republic of Lithuania', 'Taurage county']
# ['Pagėgiai mun.', '2015', '5971', 'Republic of Lithuania', 'Taurage county']
# ['Šilalė d. mun.', '2015', '12835', 'Republic of Lithuania', 'Taurage county']
# ['Tauragė d. mun.', '2015', '41094', 'Republic of Lithuania', 'Taurage county']
# ['Mažeikiai d. mun.', '2015', '76549', 'Republic of Lithuania', 'Telsiai county']
# ['Plungė d. mun.', '2015', '46127', 'Republic of Lithuania', 'Telsiai county']
# ['Rietavas mun.', '2015', '8867', 'Republic of Lithuania', 'Telsiai county']
# ['Telšiai d. mun.', '2015', '49464', 'Republic of Lithuania', 'Telsiai county']
# ['Anykščiai d. mun.', '2015', '12423', 'Republic of Lithuania', 'Utena county']
# ['Ignalina d. mun.', '2015', '12939', 'Republic of Lithuania', 'Utena county']
# ['Molėtai d. mun.', '2015', '14090', 'Republic of Lithuania', 'Utena county']
# ['Utena d. mun.', '2015', '70873', 'Republic of Lithuania', 'Utena county']
# ['Visaginas mun.', '2015', '53313', 'Republic of Lithuania', 'Utena county']
# ['Zarasai d. mun.', '2015', '8747', 'Republic of Lithuania', 'Utena county']
# ['Elektrėnai mun.', '2015', '48720', 'Republic of Lithuania', 'Vilnius county']
# ['Šalčininkai d. mun.', '2015', '16442', 'Republic of Lithuania', 'Vilnius county']
# ['Širvintos d. mun.', '2015', '10150', 'Republic of Lithuania', 'Vilnius county']
# ['Švenčionys d. mun.', '2015', '27117', 'Republic of Lithuania', 'Vilnius county']
# ['Trakai d. mun.', '2015', '62381', 'Republic of Lithuania', 'Vilnius county']
# ['Ukmergė d. mun.', '2015', '28490', 'Republic of Lithuania', 'Vilnius county']
# ['Vilnius c. mun.', '2015', '1810179', 'Republic of Lithuania', 'Vilnius county']
# ['Vilnius d. mun.', '2015', '192791', 'Republic of Lithuania', 'Vilnius county']

# %%
#Adding collumn headers istead of the melformed header
headerList=['Municipality','Time_period','Investment_in_tangible_fixed_assets_at_current_prices_EUR_thousand','Country','County']
del data[0]
data.insert( 0, headerList)
for row_num in range(0,len(data)):
    print (data[row_num])
# Out:
# ['Municipality', 'Time_period', 'Investment_in_tangible_fixed_assets_at_current_prices_EUR_thousand', 'Country', 'County']
# ['Alytus t. mun.', '2015', '60726', 'Republic of Lithuania', 'Alytus county']
# ['Alytus d. mun.', '2015', '144157', 'Republic of Lithuania', 'Alytus county']
# ['Druskininkai mun.', '2015', '31103', 'Republic of Lithuania', 'Alytus county']
# ['Lazdijai d. mun.', '2015', '8072', 'Republic of Lithuania', 'Alytus county']
# ['Varėna d. mun.', '2015', '17260', 'Republic of Lithuania', 'Alytus county']
# ['Birštonas mun.', '2015', '6095', 'Republic of Lithuania', 'Kanuas county']
# ['Jonava d. mun.', '2015', '84388', 'Republic of Lithuania', 'Kanuas county']
# ['Kaišiadorys d. mun.', '2015', '35612', 'Republic of Lithuania', 'Kanuas county']
# ['Kaunas c. mun.', '2015', '614537', 'Republic of Lithuania', 'Kanuas county']
# ['Kaunas d. mun.', '2015', '198011', 'Republic of Lithuania', 'Kanuas county']
# ['Kėdainiai d. mun.', '2015', '71893', 'Republic of Lithuania', 'Kanuas county']
# ['Prienai d. mun.', '2015', '14409', 'Republic of Lithuania', 'Kanuas county']
# ['Raseiniai d. mun.', '2015', '22954', 'Republic of Lithuania', 'Kanuas county']
# ['Klaipėda c. mun.', '2015', '483394', 'Republic of Lithuania', 'Klaipeda county']
# ['Klaipėda d. mun.', '2015', '283588', 'Republic of Lithuania', 'Klaipeda county']
# ['Kretinga d. mun.', '2015', '36191', 'Republic of Lithuania', 'Klaipeda county']
# ['Neringa mun.', '2015', '12044', 'Republic of Lithuania', 'Klaipeda county']
# ['Palanga t. mun.', '2015', '48346', 'Republic of Lithuania', 'Klaipeda county']
# ['Skuodas d. mun.', '2015', '6824', 'Republic of Lithuania', 'Klaipeda county']
# ['Šilutė d. mun.', '2015', '42816', 'Republic of Lithuania', 'Klaipeda county']
# ['Kalvarija mun.', '2015', '9378', 'Republic of Lithuania', 'Marijampole county']
# ['Kazlų Rūda mun.', '2015', '11172', 'Republic of Lithuania', 'Marijampole county']
# ['Marijampolė mun.', '2015', '97519', 'Republic of Lithuania', 'Marijampole county']
# ['Marijampolė d. mun.', '2015', '', 'Republic of Lithuania', 'Marijampole county']
# ['Šakiai d. mun.', '2015', '25717', 'Republic of Lithuania', 'Marijampole county']
# ['Vilkaviškis d. mun.', '2015', '21378', 'Republic of Lithuania', 'Marijampole county']
# ['Biržai d. mun.', '2015', '15418', 'Republic of Lithuania', 'Panevezys county']
# ['Kupiškis d. mun.', '2015', '13551', 'Republic of Lithuania', 'Panevezys county']
# ['Panevėžys c. mun.', '2015', '123142', 'Republic of Lithuania', 'Panevezys county']
# ['Panevėžys d. mun.', '2015', '37861', 'Republic of Lithuania', 'Panevezys county']
# ['Pasvalys d. mun.', '2015', '21101', 'Republic of Lithuania', 'Panevezys county']
# ['Rokiškis d. mun.', '2015', '24783', 'Republic of Lithuania', 'Panevezys county']
# ['Akmenė d. mun.', '2015', '18471', 'Republic of Lithuania', 'Siauliai county']
# ['Joniškis d. mun.', '2015', '20784', 'Republic of Lithuania', 'Siauliai county']
# ['Kelmė d. mun.', '2015', '12555', 'Republic of Lithuania', 'Siauliai county']
# ['Pakruojis d. mun.', '2015', '24957', 'Republic of Lithuania', 'Siauliai county']
# ['Radviliškis d. mun.', '2015', '27713', 'Republic of Lithuania', 'Siauliai county']
# ['Šiauliai c. mun.', '2015', '212544', 'Republic of Lithuania', 'Siauliai county']
# ['Šiauliai d. mun.', '2015', '71391', 'Republic of Lithuania', 'Siauliai county']
# ['Jurbarkas d. mun.', '2015', '20444', 'Republic of Lithuania', 'Taurage county']
# ['Pagėgiai mun.', '2015', '5971', 'Republic of Lithuania', 'Taurage county']
# ['Šilalė d. mun.', '2015', '12835', 'Republic of Lithuania', 'Taurage county']
# ['Tauragė d. mun.', '2015', '41094', 'Republic of Lithuania', 'Taurage county']
# ['Mažeikiai d. mun.', '2015', '76549', 'Republic of Lithuania', 'Telsiai county']
# ['Plungė d. mun.', '2015', '46127', 'Republic of Lithuania', 'Telsiai county']
# ['Rietavas mun.', '2015', '8867', 'Republic of Lithuania', 'Telsiai county']
# ['Telšiai d. mun.', '2015', '49464', 'Republic of Lithuania', 'Telsiai county']
# ['Anykščiai d. mun.', '2015', '12423', 'Republic of Lithuania', 'Utena county']
# ['Ignalina d. mun.', '2015', '12939', 'Republic of Lithuania', 'Utena county']
# ['Molėtai d. mun.', '2015', '14090', 'Republic of Lithuania', 'Utena county']
# ['Utena d. mun.', '2015', '70873', 'Republic of Lithuania', 'Utena county']
# ['Visaginas mun.', '2015', '53313', 'Republic of Lithuania', 'Utena county']
# ['Zarasai d. mun.', '2015', '8747', 'Republic of Lithuania', 'Utena county']
# ['Elektrėnai mun.', '2015', '48720', 'Republic of Lithuania', 'Vilnius county']
# ['Šalčininkai d. mun.', '2015', '16442', 'Republic of Lithuania', 'Vilnius county']
# ['Širvintos d. mun.', '2015', '10150', 'Republic of Lithuania', 'Vilnius county']
# ['Švenčionys d. mun.', '2015', '27117', 'Republic of Lithuania', 'Vilnius county']
# ['Trakai d. mun.', '2015', '62381', 'Republic of Lithuania', 'Vilnius county']
# ['Ukmergė d. mun.', '2015', '28490', 'Republic of Lithuania', 'Vilnius county']
# ['Vilnius c. mun.', '2015', '1810179', 'Republic of Lithuania', 'Vilnius county']
# ['Vilnius d. mun.', '2015', '192791', 'Republic of Lithuania', 'Vilnius county']

# %%
import csv
#print (data)
with open("Ready_datasets/readyDataSet6.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(data)
